# %%
import json
import requests
from bs4 import BeautifulSoup

# %%
def weworkremotely_jobs():
    r = requests.get("https://weworkremotely.com/")
    page = BeautifulSoup(r.text, "html.parser")
    job_section = page.find("section", {"id": "category-2"})
    
    jobs = []
    for job in job_section.find_all("li", {"class": "feature"}):
        jobs.append({
            "href": "https://weworkremotely.com" + job.find_all("a")[1]["href"],
            "company": job.find("span", {"class": "company"}).text.strip(),
            "role": job.find("span", {"class": "title"}).text.strip(),
            "job_type": job.find_all("span", {"class": "company"})[1].text.strip(),
            "location": job.find("span", {"class": "region company"}).text.strip()
        })
    return jobs

# %%
def weworkremotely_info(href):
    r = requests.get(href)
    page = BeautifulSoup(r.text, "html.parser")
    
    title = page.find("div", {"class": "listing-header-container"}).find("h1").text.strip()
    tags = [i.text.strip() for i in page.find_all("span", {"class": "listing-tag"})]
    return {
        "title": title,
        "tags": tags,
        "href": href
    }

# %%
def remoteok_jobs():
    r = requests.get("https://remoteok.io/remote-dev-jobs")
    page = BeautifulSoup(r.text, "html.parser")
    
    first_index = str(page).find("<thead>")
    second_index = str(page)[first_index + 7:].find("<thead>")
    job_section = BeautifulSoup(str(page)[first_index:second_index], "html.parser")
    
    jobs = []
    for job in job_section.find_all("tr", {"class": "job"}):
        try:
            job_info = json.loads(str(job.find("script"))[35:-9])
            jobs.append({
                "href": "https://remoteok.io" + job["data-url"],
                "company": job_info["hiringOrganization"]["name"],
                "role": job_info["title"],
                "job_type": job_info["employmentType"],
                "location": job_info["jobLocation"]["address"]["addressCountry"],
                "tags": [i.text.strip() for i in job.find("td", {"class": "tags"}).find_all("h3")]
            })
        except:
            pass
    return jobs

# %%
def employremotely_jobs():
    r = requests.get("https://www.employremotely.com/jobs")
    page = BeautifulSoup(r.text, "html.parser")
    
    jobs = []
    for job in page.find_all("div", {"class": "c-job-card"}):
        jobs.append({
            "href": "https://www.employremotely.com" + job.find("span", {"class": "c-job-card__job-title"}).find("a")["href"],
            "company": job.find("span", {"class": "c-job-card__company"}).text.strip(),
            "role": job.find("span", {"class": "c-job-card__job-title"}).find("a").text.strip(),
            "job_type": job.find("span", {"class": "c-job-card__contract-type"}).text.strip(),
            "location": job.find("span", {"class": "c-job-card__location"}).text.strip()
        })
    return jobs

# %%
def employremotely_info(href):
    r = requests.get(href)
    page = BeautifulSoup(r.text, "html.parser")
    
    title = page.find("h1", {"class": "u-c--white"}).text.strip()
    deadline = page.find_all("span", {"class": "job-header__detail"})[-1].text.strip()
    tags = [i.text.strip() for i in page.find("section", {"class": "job-information__tags"}).find_all("span", {"class": "c-pill"})]
    return {
        "title": title,
        "tags": tags,
        "deadline": deadline,
        "href": href
    }

# %%
def remotive_jobs():
    r = requests.get("https://remotive.io/remote-jobs/software-dev")
    page = BeautifulSoup(r.text, "html.parser")
    job_section = page.find("ul", {"class": "job-list"})
    
    jobs = []
    for job in job_section.find_all("li"):
        if job.find("span", {"class": "job-date--old"}):
            continue
        try:
            location = job.find("span", {"class": "location"}).text.strip()
        except:
            location = ""
        jobs.append({
            "href": "https://remotive.io" + job["data-url"],
            "company": job.find("div", {"class": "company"}).find("span").text.strip(),
            "role": job.find("a").text.strip(),
            "location": location,
            "tags": [i.text.strip() for i in job.find_all("a", {"class": "job-tag"})]
        })
    return jobs

# %%
def stackoverflow_jobs():
    r = requests.get("https://stackoverflow.com/jobs")
    page = BeautifulSoup(r.text, "html.parser")
    job_section = page.find("div", {"class": "listResults"})
    
    jobs = []
    for job in job_section.find_all("div", {"class": "-job"}):
        jobs.append({
            "href": "https://stackoverflow.com" + job.find("a", {"class": "s-link"})["href"],
            "location": job.find_all("span")[1].text.strip(),
            "company": job.find("h3", {"class": "fc-black-700"}).find("span").text.strip(),
            "role": job.find("a", {"class": "s-link"})["title"],
            "tags": [i.text.strip() for i in job.find_all("a", {"class": "post-tag"})]
        })
    return jobs

# %%
stackoverflow_jobs()
# Out:
# [{'href': 'https://stackoverflow.com/jobs/428691/software-engineering-jpmorgan-chase-bank-na',
#   'location': 'JPMorgan Chase Bank, N.A.',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'role': 'Software Engineering',
#   'tags': ['java', 'soap', 'api']},
#  {'href': 'https://stackoverflow.com/jobs/428787/react-js-developer-software-developer-talent-corner-hr-services',
#   'location': 'Bengaluru, India',
#   'company': 'Talent Corner Hr Services Private Limited',
#   'role': 'React JS Developer, Software Developer',
#   'tags': ['reactjs', 'javascript', 'jquery']},
#  {'href': 'https://stackoverflow.com/jobs/425143/dot-net-developer-bangalore-software-engineer-c-p-careers-private-limited',
#   'location': 'Bengaluru, India',
#   'company': 'C P Careers Private Limited',
#   'role': 'Dot Net Developer - Bangalore, Software Engineer/Programmer',
#   'tags': ['c#', '.net', 'asp.net-mvc']},
#  {'href': 'https://stackoverflow.com/jobs/428808/senior-backend-php-developer-arrow2web-technologies-pvt-ltd',
#   'location': 'Kolkata, India',
#   'company': 'Arrow2web Technologies Pvt Ltd',
#   'role': 'Senior Backend Php Developer',
#   'tags': ['php', 'mysql', 'javascript']},
#  {'href': 'https://stackoverflow.com/jobs/428790/react-native-developer-software-developer-talent-corner-hr-services',
#   'location': 'Bengaluru, India',
#   'company': 'Talent Corner Hr Services Private Limited',
#   'role': 'React Native Developer, Software Developer',
#   'tags': ['reactjs', 'javascript', 'java']},
#  {'href': 'https://stackoverflow.com/jobs/392151/looking-for-magneto-developer-weft-technologies-pvt-ltd',
#   'location': 'Kochi, India',
#   'company': 'Weft Technologies Pvt Ltd',
#   'role': 'looking for Magneto Developer',
#   'tags': ['php', 'mysql', 'jquery']},
#  {'href': 'https://stackoverflow.com/jobs/424690/front-end-developer-software-engineer-programmer-global-technologies',
#   'location': 'Pune, India',
#   'company': 'Global Technologies',
#   'role': 'FRONT END DEVELOPER, Software Engineer/Programmer',
#   'tags': ['user-experience', 'javascript', 'user-interface']},
#  {'href': 'https://stackoverflow.com/jobs/268694/senior-backend-developer-were-motivated-to-kind',
#   'location': 'Malmö, Sweden',
#   'company': 'Kind',
#   'role': "Senior Backend Developer - We're motivated to code with a sense of purpose",
#   'tags': ['microservices',
#    'kubernetes',
#    'spring-boot',
#    'java',
#    'javascript']},
#  {'href': 'https://stackoverflow.com/jobs/428737/backend-software-engineer-smartnews',
#   'location': 'San Francisco, CA',
#   'company': 'SmartNews',
#   'role': 'Backend Software Engineer',
#   'tags': ['java', 'python', 'amazon-web-services', 'c++']},
#  {'href': 'https://stackoverflow.com/jobs/393587/staff-software-engineer-stott-and-may-inc',
#   'location': 'via',
#   'company': 'Stott and May Inc.\r\n                        via\r\nStott and May Inc.',
#   'role': 'Staff Software Engineer',
#   'tags': ['c#', 'python', 'go', 'kubernetes', 'amazon-web-services']},
#  {'href': 'https://stackoverflow.com/jobs/428753/php-developer-codebucket-solutions-private',
#   'location': 'Kochi, India',
#   'company': 'Codebucket Solutions Private Limited',
#   'role': 'PHP Developer',
#   'tags': ['php', 'javascript', 'jquery']},
#  {'href': 'https://stackoverflow.com/jobs/428095/full-stack-engineer-switch-payments',
#   'location': 'Porto, Portugal',
#   'company': 'Switch Payments',
#   'role': 'Full Stack Engineer',
#   'tags': ['django', 'microservices', 'mongodb', 'postgresql', 'docker']},
#  {'href': 'https://stackoverflow.com/jobs/428542/team-lead-senior-software-developer-relex',
#   'location': 'Helsinki, Finland',
#   'company': 'RELEX',
#   'role': 'Team Lead / Senior Software Developer',
#   'tags': ['reactjs', 'typescript', 'microservices', 'node.js']},
#  {'href': 'https://stackoverflow.com/jobs/428324/urgent-opening-for-php-developer-at-mulund-t7e-aftermarket-connect-pvt',
#   'location': 'Mumbai, India',
#   'company': 'T7E Aftermarket Connect Pvt. Ltd.',
#   'role': 'Urgent Opening for PHP Developer at Mulund',
#   'tags': ['php', 'mysql', 'javascript']},
#  {'href': 'https://stackoverflow.com/jobs/424948/front-end-developer-m-f-d-for-berlin-based-mvp-venture-leap-gmbh',
#   'location': 'Berlin, Deutschland',
#   'company': 'Venture Leap GmbH',
#   'role': 'Front-End Developer (m/f/d) for Berlin-based MVP Startup',
#   'tags': ['javascript', 'css', 'html', 'reactjs', 'react-native']},
#  {'href': 'https://stackoverflow.com/jobs/393647/software-engineering-lead-stott-and-may-inc',
#   'location': 'via',
#   'company': 'Stott and May Inc.\r\n                        via\r\nStott and May Inc.',
#   'role': 'Software Engineering Lead',
#   'tags': ['go', 'python', 'c#', 'distributed-system', 'kubernetes']},
#  {'href': 'https://stackoverflow.com/jobs/428730/software-engineer-shapeshift',
#   'location': 'Denver, CO',
#   'company': 'ShapeShift',
#   'role': 'Software Engineer',
#   'tags': ['node.js', 'reactjs', 'javascript']},
#  {'href': 'https://stackoverflow.com/jobs/428712/software-engineering-jpmorgan-chase-bank-na',
#   'location': 'Chicago, IL',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'role': 'Software Engineering',
#   'tags': ['java', 'soap', 'api']},
#  {'href': 'https://stackoverflow.com/jobs/428723/senior-software-engineer-shapeshift',
#   'location': 'Denver, CO',
#   'company': 'ShapeShift',
#   'role': 'Senior Software Engineer',
#   'tags': ['reactjs', 'node.js', 'javascript', 'restapi']},
#  {'href': 'https://stackoverflow.com/jobs/428595/backend-engineering-lead-remote-till-next-year-stott-and-may-inc',
#   'location': 'via',
#   'company': 'Stott and May Inc.\r\n                        via\r\nStott and May Inc.',
#   'role': 'Backend Engineering Lead - Remote Till Next Year',
#   'tags': ['go', 'redis', 'apache-kafka', 'rabbitmq', 'amazon-web-services']},
#  {'href': 'https://stackoverflow.com/jobs/428049/full-stack-web-developer-for-covid19-research-universit-sharp228-t-bern',
#   'location': 'Bern, Switzerland',
#   'company': 'Universit&#228;t Bern',
#   'role': 'Full-stack web developer for COVID19 research project funded by the Swiss National Science Foundatio',
#   'tags': ['r', 'machine-learning', 'project-management']},
#  {'href': 'https://stackoverflow.com/jobs/427874/core-dot-net-developer-quess-corp-limited',
#   'location': 'Pune, India',
#   'company': 'Quess Corp Limited',
#   'role': 'Core Dot Net Developer',
#   'tags': ['c#', 'go', 'asp.net-mvc']},
#  {'href': 'https://stackoverflow.com/jobs/428106/senior-full-stack-software-engineer-typescript-navvis-gmbh',
#   'location': 'München, Germany',
#   'company': 'NavVis GmbH',
#   'role': 'Senior Full Stack Software Engineer (TypeScript, Angular, Java, Spring) (f/m/d)',
#   'tags': ['angular', 'java', 'spring', 'typescript', 'javascript']},
#  {'href': 'https://stackoverflow.com/jobs/330158/senior-frontend-developer-were-motivated-to-kind',
#   'location': 'Malmö, Sweden',
#   'company': 'Kind',
#   'role': "Senior Frontend Developer - We're motivated to code with a sense of purpose",
#   'tags': ['javascript', 'reactjs', 'react-native', 'react-redux']},
#  {'href': 'https://stackoverflow.com/jobs/428063/senior-python-engineer-demand-logistics-f-m-d-delivery-hero-se',
#   'location': 'Berlin, Germany',
#   'company': 'Delivery Hero SE',
#   'role': 'Senior Python Engineer - Demand, Logistics (f/m/d)',
#   'tags': ['python',
#    'postgresql',
#    'kubernetes',
#    'amazon-web-services',
#    'terraform']}]
